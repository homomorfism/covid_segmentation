# %%
import sys
from pathlib import Path
import numpy as np
import pytorch_lightning as pl
import torch
import torch.nn as nn
import wandb
from easydict import EasyDict
from pytorch_lightning.loggers import WandbLogger
from skimage import color
from torch import Generator
from torch.optim import SGD, RMSprop, Adam
from torch.utils.data import DataLoader, Dataset, random_split
import albumentations as A
from albumentations.pytorch import ToTensorV2
import segmentation_models_pytorch as smp
from pytorch_toolbelt import losses as L

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler, PopulationBasedTraining
from ray.tune.integration.pytorch_lightning import TuneReportCallback, TuneReportCheckpointCallback
pl.seed_everything(1)
# Out:
# Global seed set to 1
# 1

# %%
! wandb offline
# Out:
# W&B offline, running your script from this directory will only write metadata locally.

# %%
conf = EasyDict(
    dataset_folder=Path("/home/shamil/PycharmProjects/covid_segmentation/data/preprocessed"),
    batch_size=2,
    val_size=0.1,
)

max_epochs = 20

# %%
# Utils

def get_loss(cfg: dict):
    if cfg['loss_fn'] == 'cross_entropy':
        return nn.CrossEntropyLoss()
    elif cfg['loss_fn'] == "focal_loss":
        return smp.losses.FocalLoss(mode='binary')
    elif cfg['loss_fn'] == 'dice_loss':
        return smp.losses.DiceLoss(mode='binary')
    elif cfg['loss_fn'] == 'tversky_loss':
        return smp.losses.TverskyLoss(mode='binary')
    else:
        raise NotImplemented("Loss not found!")


def get_optimizer(cfg: dict, params, lr: float):
    if cfg['optim'] == 'SGD':
        return SGD(params, lr)
    elif cfg['optim'] == 'Adam':
        return Adam(params, lr)
    elif cfg['optim'] == 'RMSprop':
        return RMSprop(params, lr)
    else:
        raise NotImplemented("Optim not found!")


def dict_to_str(data: dict):
    result = []
    for key, value in data.items():
        line = f"{key}={value}"
        result.append(line)

    return ", ".join(result)

# %%
# Utils for visualising

def visualize_prediction(image: np.array, prediction: np.array, true: np.array):
    image = (image - image.min()) / (image.max() - image.min())
    image = color.gray2rgb(image)
    new_image = image.copy()

    red, green = (1, 0, 0), (0, 1, 0)
    image[true == 1] = red
    new_image[prediction == 1] = green
    return np.concatenate([image, new_image], axis=1)

# %%
# Augmentations

train_transform = A.Compose([
    A.OneOf([
        A.Blur(),
        A.MotionBlur(),
    ]),
    A.ShiftScaleRotate(shift_limit=0.1, rotate_limit=10),
    A.OneOf([
        A.HorizontalFlip(),
        A.VerticalFlip(),
    ]),
    A.Normalize(mean=(0.485,), std=(0.229,)),
    ToTensorV2(),
])

valid_transform = A.Compose([
    A.Normalize(mean=(0.485,), std=(0.229,)),
    ToTensorV2(),
])

# %%
class CTDataset(Dataset):
    """
    Returns
        - train - images with shape (1, 512, 512), labels with shape (512, 512) and frame name
        - test - images with shpae (1, 512, 512) and frame name
    """

    def __init__(self, transform: A.Compose, train: bool):
        self.train = train
        self.transform = transform

        if train:
            self.images = np.load(conf.dataset_folder / "training_images.npy")
            self.labels = np.load(conf.dataset_folder / "training_labels.npy")
            self.frame_names = (conf.dataset_folder / "training_frame_names.txt").read_text().split()

        else:
            self.images = np.load(conf.dataset_folder / "testing_images.npy")
            self.frame_names = (conf.dataset_folder / "testing_frame_names.txt").read_text().split()

    def __getitem__(self, item):
        image = self.images[item]
        image = np.expand_dims(image, axis=2)
        assert image.shape == (512, 512, 1)

        frame_name = self.frame_names[item]

        if self.train:
            label = self.labels[item]
            # label = np.expand_dims(label, axis=0)
            transformed = self.transform(image=image, mask=label)
            return transformed['image'], transformed['mask'], frame_name

        else:
            transformed = self.transform(image=image)
            return transformed['image'], frame_name

    def __len__(self):
        return len(self.images)

# %%
class CTDataLoader(pl.LightningDataModule):
    def __init__(self, train_aug: bool):
        super(CTDataLoader, self).__init__()

        self.train_dataset = CTDataset(train=True, transform=train_transform if train_aug else valid_transform)
        self.test_dataset = CTDataset(train=False, transform=valid_transform)

        self.val_images = int(conf.val_size * len(self.train_dataset))
        self.train_images = len(self.train_dataset) - self.val_images

    def train_dataloader(self):
        train, _ = random_split(self.train_dataset, [self.train_images, self.val_images],
                                generator=Generator().manual_seed(0))

        return DataLoader(dataset=train,
                          batch_size=conf.batch_size,
                          shuffle=True,
                          num_workers=2)

    def val_dataloader(self):
        _, val = random_split(self.train_dataset, [self.train_images, self.val_images],
                              generator=Generator().manual_seed(0))
        return DataLoader(dataset=val,
                          batch_size=conf.batch_size,
                          shuffle=False,
                          num_workers=2)

    def test_dataloader(self):
        return DataLoader(dataset=self.test_dataset,
                          batch_size=conf.batch_size,
                          shuffle=False,
                          num_workers=2)

# %%
def to_numpy(x):
    return x.detach().cpu().numpy()


class ImageLoggerCallback(pl.Callback):
    def __init__(self, train_loader: DataLoader, val_loader: DataLoader, log_batches: int = 2, threshold: float = 0.5):
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.log_batches = log_batches
        self.threshold = threshold

    def make_predictions(self, pl_module, loader):
        images, pred_masks, true_masks = [], [], []

        for ii, batch in enumerate(loader):

            if ii >= self.log_batches:
                break

            x, y, label = batch

            with torch.no_grad():
                x = x.cuda()
                output = pl_module(x)
                output = output.cpu()

            image = torch.squeeze(x)
            pred_mask = (output >= self.threshold).int().reshape(-1, 512, 512)
            true_mask = y.reshape(-1, 512, 512)

            images.extend(list(to_numpy(image)))
            pred_masks.extend(list(to_numpy(pred_mask)))
            true_masks.extend(list(to_numpy(true_mask)))

        return images, pred_masks, true_masks

    @staticmethod
    def make_grid(images, pred_masks, true_masks):
        grid = []
        for image, pred, true in zip(images, pred_masks, true_masks):
            visualization = visualize_prediction(image, pred, true)

            grid.append(visualization)

        grid = np.concatenate(grid, axis=0)
        return grid

    def on_validation_epoch_end(self, trainer: "pl.Trainer", pl_module: "pl.LightningModule") -> None:
        images, pred_masks, true_masks = self.make_predictions(pl_module, self.val_loader)
        grid = self.make_grid(images, pred_masks, true_masks)

        trainer.logger.experiment.log({
            "val/predictions": wandb.Image(grid, caption="Red are ground truth, Green are predictions"),
            "global_step": trainer.global_step
        })

    def on_train_epoch_end(self, trainer: "pl.Trainer", pl_module: "pl.LightningModule") -> None:
        images, pred_masks, true_masks = self.make_predictions(pl_module, self.train_loader)
        grid = self.make_grid(images, pred_masks, true_masks)

        trainer.logger.experiment.log({
            "train/predictions": wandb.Image(grid, caption="Red are ground truth, Green are predictions"),
            "global_step": trainer.global_step
        })

# %%
class CTSemanticSegmentation(pl.LightningModule):

    def __init__(self, cfg: dict, threshold: float = 0.5):
        super(CTSemanticSegmentation, self).__init__()
        self.model = smp.Unet('mobilenet_v2', encoder_weights="imagenet", classes=1, activation='sigmoid',
                              encoder_depth=5,
                              decoder_channels=[256, 128, 64, 32, 16], in_channels=1)

        self.cfg = cfg
        self.loss_fn = get_loss(cfg)
        self.threshold = threshold

    def forward(self, x):
        return self.model(x)

    def configure_optimizers(self):
        optimizer = get_optimizer(self.cfg, self.model.parameters(), lr=self.cfg.lr)
        return optimizer

    def training_step(self, batch, batch_idx):
        x, y, label = batch
        output = self(x)
        # print(output)
        loss = self.loss_fn(output, y)

        self.log("train/loss_step", loss.item())

        return {"loss": loss}

    def validation_step(self, batch, batch_idx):
        x, y, label = batch
        output = self(x)
        output = (output > self.threshold).int()
        loss = self.loss_fn(output, y)

        self.log("val/loss_step", loss.item())

        return {"loss": loss}

    def training_epoch_end(self, outputs) -> None:
        avg_losses = torch.hstack([loss["loss"] for loss in outputs]).mean()
        self.log("train/loss_epoch", avg_losses)

    def validation_epoch_end(self, outputs) -> None:
        avg_losses = torch.hstack([loss["loss"] for loss in outputs]).mean()
        self.log("val/loss_epoch", avg_losses)

# %%
## Tuning parameters
def train_num_epoch(hparam, num_epochs, num_gpus):
    full_config = hparam | conf.__dict__
    dataloader = CTDataLoader(train_aug=full_config['train_aug'])
    train_dataloader, val_dataloader = dataloader.train_dataloader(), dataloader.val_dataloader()

    logger = WandbLogger(name=f"{dict_to_str(hparam)}", project="CTSegmentationTuning", config=full_config)

    tune_report_callback = TuneReportCallback({
        'loss': 'val/loss_epoch'
    }, on="validation_end")

    trainer = pl.Trainer(
        logger=logger,
        gpus=num_gpus,
        max_epochs=num_epochs,
        callbacks=[tune_report_callback],
        progress_bar_refresh_rate=0
    )

    model = CTSemanticSegmentation(cfg=full_config)
    trainer.fit(model, train_dataloader, val_dataloader)


def tuning_ct_segmentation():
    tuning_conf = {
        "loss_fn": tune.choice(['cross_entropy', 'focal_loss', 'dice_loss', 'tversky_loss']),
        "optim": tune.choice(['SGD', "Adam", "RMSprop"]),
        "train_aug": tune.choice([True, False]),
        "lr": tune.choice([0.01, 0.001, 0.0001]),
    }

    scheduler = ASHAScheduler(
        max_t=max_epochs,
        grace_period=5,  # 5 train epochs before stopping some samples
        reduction_factor=4
    )

    reporter = CLIReporter(
        parameter_columns=list(tuning_conf.keys()),
        metric_columns=['loss', 'training_iteration']
    )

    analysis = tune.run(
        tune.with_parameters(
            train_num_epoch,
            num_epochs=max_epochs,
            num_gpus=0),
        resources_per_trial={
            "cpu": 1,
            "gpu": 0
        },
        metric="loss",
        mode='min',
        num_samples=72,
        config=tuning_conf,
        scheduler=scheduler,
        progress_reporter=reporter,
        name="tune_ct_segmentation")

    print(f"Best parameters found: {analysis.best_config}")
    return analysis.best_config


tuning_example = tuning_ct_segmentation()
# Out:
# == Status ==
# Current time: 2021-11-16 10:49:04 (running for 00:00:00.37)
# Memory usage on this node: 8.3/15.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.41 GiB heap, 0.0/2.71 GiB objects
# Result logdir: /home/shamil/ray_results/tune_ct_segmentation
# Number of trials: 16/72 (16 PENDING)
# +-----------------------------+----------+-------+---------------+---------+-------------+--------+
# | Trial name                  | status   | loc   | loss_fn       | optim   | train_aug   |     lr |
# |-----------------------------+----------+-------+---------------+---------+-------------+--------|
# | train_num_epoch_ab933_00000 | PENDING  |       | focal_loss    | SGD     | True        | 0.001  |
# | train_num_epoch_ab933_00001 | PENDING  |       | tversky_loss  | SGD     | True        | 0.001  |
# | train_num_epoch_ab933_00002 | PENDING  |       | focal_loss    | SGD     | True        | 0.001  |
# | train_num_epoch_ab933_00003 | PENDING  |       | dice_loss     | Adam    | True        | 0.01   |
# | train_num_epoch_ab933_00004 | PENDING  |       | dice_loss     | SGD     | False       | 0.0001 |
# | train_num_epoch_ab933_00005 | PENDING  |       | tversky_loss  | Adam    | False       | 0.0001 |
# | train_num_epoch_ab933_00006 | PENDING  |       | focal_loss    | Adam    | False       | 0.001  |
# | train_num_epoch_ab933_00007 | PENDING  |       | focal_loss    | SGD     | True        | 0.001  |
# | train_num_epoch_ab933_00008 | PENDING  |       | focal_loss    | RMSprop | False       | 0.01   |
# | train_num_epoch_ab933_00009 | PENDING  |       | tversky_loss  | RMSprop | False       | 0.001  |
# | train_num_epoch_ab933_00010 | PENDING  |       | cross_entropy | SGD     | False       | 0.01   |
# | train_num_epoch_ab933_00011 | PENDING  |       | cross_entropy | Adam    | False       | 0.001  |
# | train_num_epoch_ab933_00012 | PENDING  |       | cross_entropy | SGD     | False       | 0.0001 |
# | train_num_epoch_ab933_00013 | PENDING  |       | dice_loss     | Adam    | True        | 0.0001 |
# | train_num_epoch_ab933_00014 | PENDING  |       | tversky_loss  | RMSprop | False       | 0.001  |
# | train_num_epoch_ab933_00015 | PENDING  |       | focal_loss    | Adam    | False       | 0.0001 |
# +-----------------------------+----------+-------+---------------+---------+-------------+--------+
# (pid=18872) 2021-11-16 10:49:13,437	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18872) Traceback (most recent call last):
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18872)     self._entrypoint()
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18872)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18872)     return method(self, *_args, **_kwargs)
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18872)     output = fn()
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18872)     inner(config, checkpoint_dir=None)
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18872)     trainable(config, **fn_kwargs)
# (pid=18872)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18872)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18872)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18872)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18872) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18872) Exception in thread Thread-2:
# (pid=18872) Traceback (most recent call last):
# (pid=18872)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18872)     self.run()
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18872)     raise e
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18872)     self._entrypoint()
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18872)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18872)     return method(self, *_args, **_kwargs)
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18872)     output = fn()
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18872)     inner(config, checkpoint_dir=None)
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18872)     trainable(config, **fn_kwargs)
# (pid=18872)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18872)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18872)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18872)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18872)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18872) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18874) 2021-11-16 10:49:13,988	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18874) Traceback (most recent call last):
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18874)     self._entrypoint()
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18874)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18874)     return method(self, *_args, **_kwargs)
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18874)     output = fn()
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18874)     inner(config, checkpoint_dir=None)
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18874)     trainable(config, **fn_kwargs)
# (pid=18874)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18874)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18874)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18874)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18874) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18874) Exception in thread Thread-2:
# (pid=18874) Traceback (most recent call last):
# (pid=18874)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18874)     self.run()
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18874)     raise e
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18874)     self._entrypoint()
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18874)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18874)     return method(self, *_args, **_kwargs)
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18874)     output = fn()
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18874)     inner(config, checkpoint_dir=None)
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18874)     trainable(config, **fn_kwargs)
# (pid=18874)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18874)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18874)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18874)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18874)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18874) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18877) 2021-11-16 10:49:13,994	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18877) Traceback (most recent call last):
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18877)     self._entrypoint()
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18877)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18877)     return method(self, *_args, **_kwargs)
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18877)     output = fn()
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18877)     inner(config, checkpoint_dir=None)
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18877)     trainable(config, **fn_kwargs)
# (pid=18877)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18877)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18877)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18877)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18877) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18877) Exception in thread Thread-2:
# (pid=18877) Traceback (most recent call last):
# (pid=18877)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18877)     self.run()
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18877)     raise e
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18877)     self._entrypoint()
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18877)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18877)     return method(self, *_args, **_kwargs)
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18877)     output = fn()
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18877)     inner(config, checkpoint_dir=None)
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18877)     trainable(config, **fn_kwargs)
# (pid=18877)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18877)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18877)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18877)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18877)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18877) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18870) 2021-11-16 10:49:14,275	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18870) Traceback (most recent call last):
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18870)     self._entrypoint()
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18870)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18870)     return method(self, *_args, **_kwargs)
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18870)     output = fn()
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18870)     inner(config, checkpoint_dir=None)
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18870)     trainable(config, **fn_kwargs)
# (pid=18870)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18870)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18870)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18870)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18870) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18870) Exception in thread Thread-2:
# (pid=18870) Traceback (most recent call last):
# (pid=18870)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18870)     self.run()
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18870)     raise e
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18870)     self._entrypoint()
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18870)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18870)     return method(self, *_args, **_kwargs)
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18870)     output = fn()
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18870)     inner(config, checkpoint_dir=None)
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18870)     trainable(config, **fn_kwargs)
# (pid=18870)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18870)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18870)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18870)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18870)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18870) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18876) 2021-11-16 10:49:14,273	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18876) Traceback (most recent call last):
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18876)     self._entrypoint()
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18876)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18876)     return method(self, *_args, **_kwargs)
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18876)     output = fn()
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18876)     inner(config, checkpoint_dir=None)
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18876)     trainable(config, **fn_kwargs)
# (pid=18876)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18876)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18876)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18876)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18876) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18876) Exception in thread Thread-2:
# (pid=18876) Traceback (most recent call last):
# (pid=18876)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18876)     self.run()
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18876)     raise e
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18876)     self._entrypoint()
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18876)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18876)     return method(self, *_args, **_kwargs)
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18876)     output = fn()
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18876)     inner(config, checkpoint_dir=None)
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18876)     trainable(config, **fn_kwargs)
# (pid=18876)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18876)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18876)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18876)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18876)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18876) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18875) 2021-11-16 10:49:14,363	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18875) Traceback (most recent call last):
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18875)     self._entrypoint()
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18875)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18875)     return method(self, *_args, **_kwargs)
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18875)     output = fn()
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18875)     inner(config, checkpoint_dir=None)
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18875)     trainable(config, **fn_kwargs)
# (pid=18875)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18875)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18875)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18875)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18875) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18875) Exception in thread Thread-2:
# (pid=18875) Traceback (most recent call last):
# (pid=18875)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18875)     self.run()
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18875)     raise e
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18875)     self._entrypoint()
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18875)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18875)     return method(self, *_args, **_kwargs)
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18875)     output = fn()
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18875)     inner(config, checkpoint_dir=None)
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18875)     trainable(config, **fn_kwargs)
# (pid=18875)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18875)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18875)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18875)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18875)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18875) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18873) 2021-11-16 10:49:14,382	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18873) Traceback (most recent call last):
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18873)     self._entrypoint()
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18873)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18873)     return method(self, *_args, **_kwargs)
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18873)     output = fn()
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18873)     inner(config, checkpoint_dir=None)
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18873)     trainable(config, **fn_kwargs)
# (pid=18873)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18873)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18873)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18873)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18873) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18873) Exception in thread Thread-2:
# (pid=18873) Traceback (most recent call last):
# (pid=18873)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18873)     self.run()
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18873)     raise e
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18873)     self._entrypoint()
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18873)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18873)     return method(self, *_args, **_kwargs)
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18873)     output = fn()
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18873)     inner(config, checkpoint_dir=None)
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18873)     trainable(config, **fn_kwargs)
# (pid=18873)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18873)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18873)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18873)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18873)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18873) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:14,681	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00006: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=18873, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f16135e0d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=18873, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f16135e0d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:14,697	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00001: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=18875, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fec4f9a0d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=18875, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fec4f9a0d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:14,716	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00003: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=18872, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f8f400a1d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=18872, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f8f400a1d90>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18929) 2021-11-16 10:49:14,676	ERROR function_runner.py:268 -- Runner Thread raised error.
# (pid=18929) Traceback (most recent call last):
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18929)     self._entrypoint()
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18929)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18929)     return method(self, *_args, **_kwargs)
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18929)     output = fn()
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18929)     inner(config, checkpoint_dir=None)
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18929)     trainable(config, **fn_kwargs)
# (pid=18929)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18929)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18929)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18929)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18929) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# (pid=18929) Exception in thread Thread-2:
# (pid=18929) Traceback (most recent call last):
# (pid=18929)   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
# (pid=18929)     self.run()
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 281, in run
# (pid=18929)     raise e
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
# (pid=18929)     self._entrypoint()
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
# (pid=18929)     return self._trainable_func(self.config, self._status_reporter,
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 451, in _resume_span
# (pid=18929)     return method(self, *_args, **_kwargs)
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
# (pid=18929)     output = fn()
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
# (pid=18929)     inner(config, checkpoint_dir=None)
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
# (pid=18929)     trainable(config, **fn_kwargs)
# (pid=18929)   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
# (pid=18929)   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
# (pid=18929)   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
# (pid=18929)   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
# (pid=18929)     fid = stack.enter_context(open(os_fspath(file), "rb"))
# (pid=18929) FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:14,772	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00004: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=18876, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f6a11aa5c10>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=18876, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f6a11aa5c10>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
# ...
#   trial_id: ab933_00009
#
# Result for train_num_epoch_ab933_00015:
#   date: 2021-11-16_10-49-30
#   experiment_id: 578cc5c2fff84050b70fb0b001932eba
#   hostname: shamil-hpprobook430g7
#   node_ip: 192.168.31.72
#   pid: 19304
#   timestamp: 1637048970
#   trial_id: ab933_00015
# 2021-11-16 10:49:31,191	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00019: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=19317, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fd748180d00>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=19317, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fd748180d00>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:31,248	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00018: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=19313, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f37e0799cd0>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=19313, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7f37e0799cd0>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# 2021-11-16 10:49:31,308	ERROR trial_runner.py:924 -- Trial train_num_epoch_ab933_00017: Error processing event.
# Traceback (most recent call last):
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial_runner.py", line 890, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/ray_trial_executor.py", line 788, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py", line 1625, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=19310, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fbb07bfdb80>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 224, in train_buffered
#     result = self.train()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trainable.py", line 283, in train
#     result = self.step()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 381, in step
#     self._report_thread_runner_error(block=True)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 528, in _report_thread_runner_error
#     raise TuneError(
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=19310, ip=192.168.31.72, repr=<ray.tune.function_runner.ImplicitFunc object at 0x7fbb07bfdb80>)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 262, in run
#     self._entrypoint()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 330, in entrypoint
#     return self._trainable_func(self.config, self._status_reporter,
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/function_runner.py", line 599, in _trainable_func
#     output = fn()
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 353, in _inner
#     inner(config, checkpoint_dir=None)
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/utils/trainable.py", line 344, in inner
#     trainable(config, **fn_kwargs)
#   File "/tmp/ipykernel_15863/2430906578.py", line 4, in train_num_epoch
#   File "/tmp/ipykernel_15863/2095060557.py", line 5, in __init__
#   File "/tmp/ipykernel_15863/3108051494.py", line 13, in __init__
#   File "/home/shamil/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/training_images.npy'
# Result for train_num_epoch_ab933_00019:
#   date: 2021-11-16_10-49-30
#   experiment_id: 3a714ec3a7934fbab5e017a99cd68f77
#   hostname: shamil-hpprobook430g7
#   node_ip: 192.168.31.72
#   pid: 19317
#   timestamp: 1637048970
#   trial_id: ab933_00019
#
# Result for train_num_epoch_ab933_00018:
#   date: 2021-11-16_10-49-30
#   experiment_id: 45e72f8823504f379b9a9762d0a31391
#   hostname: shamil-hpprobook430g7
#   node_ip: 192.168.31.72
#   pid: 19313
#   timestamp: 1637048970
#   trial_id: ab933_00018
#
# Result for train_num_epoch_ab933_00017:
#   date: 2021-11-16_10-49-30
#   experiment_id: f68b7208f14342629f622cdc8cc93f32
#   hostname: shamil-hpprobook430g7
#   node_ip: 192.168.31.72
#   pid: 19310
#   timestamp: 1637048970
#   trial_id: ab933_00017
# 2021-11-16 10:49:31,992	WARNING tune.py:586 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15863/2430906578.py in <module>
#      63
#      64
# ---> 65 tuning_example = tuning_ct_segmentation()
#
# /tmp/ipykernel_15863/2430906578.py in tuning_ct_segmentation()
#      42     )
#      43
# ---> 44     analysis = tune.run(
#      45         tune.with_parameters(
#      46             train_num_epoch,
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, max_concurrent_trials, loggers, _remote)
#     610
#     611     if has_verbosity(Verbosity.V1_EXPERIMENT):
# --> 612         _report_progress(runner, progress_reporter, done=True)
#     613
#     614     wait_for_sync()
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/tune.py in _report_progress(runner, reporter, done)
#      66         sched_debug_str = runner.scheduler_alg.debug_string()
#      67         executor_debug_str = runner.trial_executor.debug_string()
# ---> 68         reporter.report(trials, done, sched_debug_str, executor_debug_str)
#      69
#      70
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/progress_reporter.py in report(self, trials, done, *sys_info)
#     518
#     519     def report(self, trials: List[Trial], done: bool, *sys_info: Dict):
# --> 520         print(self._progress_str(trials, done, *sys_info))
#     521
#     522
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/progress_reporter.py in _progress_str(self, trials, done, fmt, delim, *sys_info)
#     291             max_error = self._max_error_rows
#     292
# --> 293         current_best_trial, metric = self._current_best_trial(trials)
#     294         if current_best_trial:
#     295             messages.append(
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/progress_reporter.py in _current_best_trial(self, trials)
#     353         best_trial = None
#     354         for t in trials:
# --> 355             if not t.last_result:
#     356                 continue
#     357             if metric not in t.last_result:
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial.py in last_result(self)
#     431         result = self._last_result
#     432         if not {k for k in result if k != TRIAL_ID}:
# --> 433             self._get_default_result_or_future()
#     434             result = self._default_result_or_future or result
#     435         result.setdefault(TRIAL_ID, self.trial_id)
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/tune/trial.py in _get_default_result_or_future(self)
#     407                 self._default_result_or_future, ray.ObjectRef):
#     408             try:
# --> 409                 self._default_result_or_future = ray.get(
#     410                     self._default_result_or_future)
#     411             except RayActorError:  # error during initialization
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py in get(object_refs, timeout)
#    1616
#    1617         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1618         values, debugger_breakpoint = worker.get_objects(
#    1619             object_refs, timeout=timeout)
#    1620         for i, value in enumerate(values):
#
# ~/PycharmProjects/covid_segmentation/venv/lib/python3.9/site-packages/ray/worker.py in get_objects(self, object_refs, timeout)
#     342
#     343         timeout_ms = int(timeout * 1000) if timeout else -1
# --> 344         data_metadata_pairs = self.core_worker.get_objects(
#     345             object_refs, self.current_task_id, timeout_ms)
#     346         debugger_breakpoint = b""
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.get_objects()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:
